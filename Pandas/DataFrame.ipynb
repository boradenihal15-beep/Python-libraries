# %% [markdown]
# <a href="https://colab.research.google.com/github/boradenihal15-beep/Python-libraries/blob/main/Pandas/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DataFrame**

# %% [markdown]
# Dataset : https://drive.google.com/drive/folders/18ZsL5K8PiFT9GS1631lpGIE3HMR0n1G8

# %%
import pandas as pd
import numpy as np

# %%
#List
student_data=[
    [1,90,18],
    [2,50,17]
]
df_st=pd.DataFrame(student_data,columns=['Roll_no','Marks','Age'])
df_st.set_index('Roll_no',inplace=True)
print(df_st)
# Out:
#          Marks  Age
# Roll_no
# 1           90   18
# 2           50   17

# %%
student_dict={
    'Name':['Nihal','karan','varan'],
    'Roll_no':[1,2,3],
    'Marks':[90,80,50],
    'Age':[18,17,18]
}
df_students=pd.DataFrame(student_dict)
df_students.set_index('Name',inplace=True)
print(df_students)
# Out:
#        Roll_no  Marks  Age
# Name
# Nihal        1     90   18
# karan        2     80   17
# varan        3     50   18

# %% [markdown]
# Reading the data

# %%
movies=pd.read_csv('movies.csv')
ipl=pd.read_csv('ipl-matches.csv')

# %% [markdown]
# Attributs and methods

# %%
#Shape
movies.shape

#dtype
movies.dtypes

#index
movies.index

#columns
movies.columns

#values
df_students.values
# Out:
# array([[ 1, 90, 18],
#        [ 2, 80, 17],
#        [ 3, 50, 18]])

# %%
#head and tail
movies.head(6) #default 5

movies.tail(4) #default 5
# Out:
#                    title_x     imdb_id  \
# 1625  Yeh Zindagi Ka Safar   tt0298607
# 1626       Sabse Bada Sukh   tt0069204
# 1627                 Daaka  tt10833860
# 1628              Humsafar   tt2403201
#
#                                             poster_path  \
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...  Yeh Zindagi Ka Safar
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh       Sabse Bada Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka                 Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar              Humsafar
#
#             original_title  is_adult  year_of_release runtime         genres  \
# ...

# %%
#sample
movies.sample(3) #random row default 1
# Out:
#                   title_x    imdb_id  \
# 217            Qaidi Band  tt5617172
# 961  Main Aurr Mrs Khanna  tt1174041
# 662    Ek Main Aur Ekk Tu  tt1703958
#
#                                            poster_path  \
# 217  https://upload.wikimedia.org/wikipedia/en/thum...
# 961  https://upload.wikimedia.org/wikipedia/en/thum...
# 662  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link               title_y  \
# 217           https://en.wikipedia.org/wiki/Qaidi_Band            Qaidi Band
# 961  https://en.wikipedia.org/wiki/Main_Aurr_Mrs_Kh...  Main Aurr Mrs Khanna
# 662   https://en.wikipedia.org/wiki/Ek_Main_Aur_Ekk_Tu    Ek Main Aur Ekk Tu
#
#            original_title  is_adult  year_of_release runtime  \
# 217            Qaidi Band         0             2017     119
# 961  Main Aurr Mrs Khanna         0             2009     109
# 662    Ek Main Aur Ekk Tu         0             2012     110
#
# ...

# %%
#info
movies.info()

#descibe
movies.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#isnull
movies.isnull().sum()

#fillna
movies['wins_nominations'].fillna('0 wins') #filled Nan values with 0 wins

#dropna
movies.dropna() #mostly not used bcoz of loss of data
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#duplicates
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename

#columns
df_students.rename(columns={'Name':'Naav','Marks':'Score'},inplace=True)
df_students
# Out:
#        Roll_no  Score  Age
# Name
# Nihal        1     90   18
# karan        2     80   17
# varan        3     50   18

# %% [markdown]
# # Maths Methods

# %%
#sum
df_students.sum(axis=0) #column wise
df_st.sum(axis=1) #row wise

#mean
df_st.mean(axis=1) #row wise

#variance
df_st.var(axis=1) #row wise
# Out:
# Roll_no
# 1    2592.0
# 2     544.5
# dtype: float64

# %% [markdown]
# Selecting columns from Dataframe

# %%
#single colmns
movies['actors']

#multiple columns
movies[['actors','title_x']]
# Out:
#                                                  actors  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                          Gippy Grewal|Zareen Khan|
# 1628                                        Fawad Khan|
#
#                                    title_x
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...

# %% [markdown]
# Selecting rows

# %%
#iloc
#use only in index is numrical

df_students.iloc[1]
df_students.iloc[[1,2]]
df_students[:2]
df_students[0::2]
df_students[::-1]

#loc
df_students.loc['Nihal']
df_students.loc[['Nihal','karan']]
df_students.loc['Nihal':'varan']
df_students.loc['Nihal':'varan':2]
df_students.loc[::-1]
# Out:
#        Roll_no  Score  Age
# Name
# varan        3     50   18
# karan        2     80   17
# Nihal        1     90   18

# %% [markdown]
# Filtering

# %%
# find all the final winners
finals=ipl[ipl['MatchNumber']=='Final']
finals[['Season','WinningTeam']]

# how many super over finishes have occured
ipl[ipl['SuperOver']=='Y'].shape[0]

# how many matches has csk won in kolkata
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=="Chennai Super Kings")].shape[0] #use & bitwise op

# toss winner is match winner in percentage
((ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0])/ipl.shape[0])*100

# movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating']>8.5) & (movies['imdb_votes']>10000)].shape[0]

# Action movies with rating higher than 7.5
movies[(movies['genres']=='Action') & (movies['imdb_rating']>7.5)]
# Out:
# Empty DataFrame
# Columns: [title_x, imdb_id, poster_path, wiki_link, title_y, original_title, is_adult, year_of_release, runtime, genres, imdb_rating, imdb_votes, story, summary, tagline, actors, wins_nominations, release_date]
# Index: []

# %%
#Adding new columns

#completly new column
movies['country']='india'
movies.head()

#from existing
movies.dropna(inplace=True)

movies['lead']=movies['actors'].str.split('|').apply(lambda x:x[0])
movies.head()
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
# 87            Aiyaary   tt6774212
# 96   Raid (2018 film)   tt7363076
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
# 87  https://upload.wikimedia.org/wikipedia/en/thum...
# 96  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
# 87            https://en.wikipedia.org/wiki/Aiyaary        Aiyaary
# 96   https://en.wikipedia.org/wiki/Raid_(2018_film)           Raid
#
# ...

# %%
#astype

ipl.info()
ipl['ID']=ipl['ID'].astype('int16')
ipl.info()

ipl['Team1']=ipl['Team1'].astype('category')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# value_counts
ipl['City'].value_counts()
# Out:
# City
# Mumbai            159
# Kolkata            79
# Delhi              78
# Chennai            67
# Bangalore          65
# Hyderabad          64
# Chandigarh         56
# Pune               51
# Jaipur             47
# Abu Dhabi          37
# Ahmedabad          19
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Dubai              13
# Centurion          12
# Sharjah            10
# Rajkot             10
# Navi Mumbai         9
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Port Elizabeth      7
# Cuttack             7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
# find which player has won most potm -> in finals and qualifiers

ipl.head()
# Out:
#      ID       City        Date Season  MatchNumber  \
# 0  1480  Ahmedabad  2022-05-29   2022        Final
# 1  1479  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1478    Kolkata  2022-05-25   2022   Eliminator
# 3  1477    Kolkata  2022-05-24   2022  Qualifier 1
# 4 -6604     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
# Toss decision plot
ipl['TossDecision'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TossDecision'>

# %%
# how many matches each team has played
ipl[['Team1']].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Kochi Tuskers Kerala             7
# Gujarat Titans                   7
# Rising Pune Supergiants          7
# Rising Pune Supergiant           7
# Name: count, dtype: int64

# %%
movies.info()
movies['year_of_release'].astype('int16')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
# ...

# %%
#between

ipl[ipl['Season'].between('2007','2021')].size
# Out:
# 17520

# %%
#clip
df_students['Score'].clip(60,80)
# Out:
# Name
# Nihal    80
# karan    80
# varan    60
# Name: Score, dtype: int64

# %%
#drop_duplicate

df=pd.read_csv('diabetes.csv')

df.drop_duplicates()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...
