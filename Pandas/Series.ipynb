# %% [markdown]
# <a href="https://colab.research.google.com/github/boradenihal15-beep/Python-libraries/blob/main/Pandas/Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# what is pandas?
# *   Pandas is powerfull library build on numpy
# *   Pandas is used for Data collection,abstraction,manipulation,cleaning

# %% [markdown]
# # **Series**

# %% [markdown]
# Dataset : https://drive.google.com/drive/folders/1IfYgDQzE8B_VOAik6Qha06Ok-NXLb98q

# %% [markdown]
# Import pandas

# %%
import numpy as np
import pandas as pd

# %%
#string
string=['hi','bye','why']
series=pd.Series(string)
series
# Out:
# 0     hi
# 1    bye
# 2    why
# dtype: object

# %%
#intergers
intergers=[1,3,2,4,5]
series=pd.Series(intergers)
series
# Out:
# 0    1
# 1    3
# 2    2
# 3    4
# 4    5
# dtype: int64

# %%
#custom index
names=['karan','varan']
marks=[90,60]

students=pd.Series(data=marks,index=names)

students
# Out:
# karan    90
# varan    60
# dtype: int64

# %%
#Name to series
names=['karan','varan']
marks=[90,60]

students=pd.Series(data=marks,index=names,name='student_marks')

students
# Out:
# karan    90
# varan    60
# Name: student_marks, dtype: int64

# %%
#Series of dict
marks={
    'Nihal':90,
    'karan':40,
    'Nihal':30
}
students=pd.Series(marks)
students
# Out:
# Nihal    30
# karan    40
# dtype: int64

# %%
#Attributes of series

#size
students.size

#dtype
students.dtype

#index
students.index

#values
students.values

#isunique
students.is_unique
# Out:
# True

# %%
#Reading the dataset

#one column
data=pd.read_csv("subs.csv")
subs=data.squeeze()
subs

#Two column
data=pd.read_csv('kohli_ipl.csv')
vk=data['runs'].squeeze()

data=pd.read_csv('bollywood.csv')
movies=data['lead'].squeeze()

# %%
#head and tail
movies.head() #first default 5
movies.tail() #last default 5
movies.head(15) #first 15

movies.sample() #random value
movies.sample(3) #random 3 value
# Out:
# 767      Kainaz Motivala
# 383          Irrfan Khan
# 498    Himesh Reshammiya
# Name: lead, dtype: object

# %%
#value count
movies.value_counts() #total movies of actress (total values of index)
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
#sort values
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
#sort by index
data=pd.read_csv('kohli_ipl.csv')
vk=pd.Series(data=data['runs'],index=data['match_no'])
vk.sort_index()
# Out:
# match_no
# 1      23.0
# 2      13.0
# 3      12.0
# 4       1.0
# 5       9.0
#        ...
# 211    20.0
# 212    73.0
# 213    25.0
# 214     7.0
# 215     NaN
# Name: runs, Length: 215, dtype: float64

# %%
#maths methods

#count
vk.count()

#sum
subs.sum()

#product
subs.product()

# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.67502303725269
# 687.0281470756001

# %%
# min/max
subs.min()
subs.max()
# Out:
# 396

# %%
#descibe
vk.describe()
# Out:
# count    214.000000
# mean      30.995327
# std       26.211222
# min        0.000000
# 25%        9.250000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
#indexing

#pos indexing
subs[1]

#Neg indexing
# subs[-1] #gives error
students[-1] #works only for custom indexes

#string index
students['Nihal']
# Out:
# /tmp/ipykernel_1991/3863113971.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   students[-1] #works only for custom indexes
# np.int64(30)

# %%
#Slicing
vk[1:6]
vk[:6:2]
vk[-5::]
vk[::-1]
# Out:
# match_no
# 215     NaN
# 214     7.0
# 213    25.0
# 212    73.0
# 211    20.0
#        ...
# 5       9.0
# 4       1.0
# 3      12.0
# 2      13.0
# 1      23.0
# Name: runs, Length: 215, dtype: float64

# %%
#fancy indexing
subs[[1,3,4]]
# Out:
# 1    57
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
#Editing series

students[1]=40
students['Nihal']=40
students
students['suraj']=100
students

#by slicing
students[1:2]=100
students

#by fancy indexing
students[[0,2]]=100
students
# Out:
# /tmp/ipykernel_1991/4006472422.py:3: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   students[1]=40
# /tmp/ipykernel_1991/4006472422.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   students[[0,2]]=100
# Nihal    100
# karan    100
# suraj    100
# dtype: int64

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
#type conversion
list(students)
dict(students)
# Out:
# {'Nihal': np.int64(100), 'karan': np.int64(100), 'suraj': np.int64(100)}

# %%
#Membership operators

'Nihal' in students #it is based on index
100 in students.values #to check in values
# Out:
# True

# %%
#looping

#looping is based on values
for i in students:
  print(i)

for i in students.index: #to do on indexes
  print(i)
# Out:
# 100
# 100
# 100
# Nihal
# karan
# suraj

# %%
#Arithmatic operator
100+students #also called as broadcasting one values is added to all rows
# Out:
# Nihal    200
# karan    200
# suraj    200
# dtype: int64

# %%
#relational operator
vk[vk>100]
# Out:
# match_no
# 122    108.0
# 125    109.0
# 127    113.0
# Name: runs, dtype: float64

# %%
#Boolean index

#No of 50's
vk[vk>50].count()

#Actor more than 20 movies
count=movies.value_counts()
count[count>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
#Graph plot

subs.plot()

movies.value_counts().head(5).plot(kind='bar')
movies.value_counts().head(5).plot(kind='pie')
# Out:
# <Axes: xlabel='lead', ylabel='count'>

# %%
#astype

#used to change the datatype

import sys
sys.getsizeof(vk)
vk #as it is large in size

sys.getsizeof(vk.astype('float16')) #after this size will dec
# Out:
# 10478

# %%
#between
vk[vk.between(51,99)].size
# Out:
# 43

# %%
#clip
#clip the values below min to min and abov max to max

subs.clip(100,200) #now the values below 100 becames 100 and above 200 becames 200 and middle values remain as it is
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#drop_duplicates

subs.duplicated().sum()

subs.drop_duplicates(inplace=True)
subs.duplicated().sum()
# Out:
# np.int64(0)

# %%
#isnull
vk.isnull().sum()

#dropna
vk.dropna(inplace=True)
vk.isnull().sum()

#fillna
vk.fillna(vk.mean(),inplace=True)
vk.isnull().sum()
# Out:
# np.int64(0)

# %%
#isin
vk[(vk==50) | (vk==100)]

#basically is a or condition
vk[vk.isin([50,100])]
# Out:
# match_no
# 14      50.0
# 119    100.0
# 163    100.0
# 181     50.0
# Name: runs, dtype: float64

# %%
#apply

movies.apply(lambda x:x.split()[0].upper())

subs.apply(lambda x:'good day' if x>subs.mean() else 'bad day')

vk.apply(lambda x:'century' if x>100 else 'normal')
# Out:
# match_no
# 1      normal
# 2      normal
# 3      normal
# 4      normal
# 5      normal
#         ...
# 211    normal
# 212    normal
# 213    normal
# 214    normal
# 215    normal
# Name: runs, Length: 215, dtype: object

# %%
subs.sum()
# Out:
# np.int64(49510)

# %%
vk[[1,3,5]]
# Out:
# match_no
# 1    23.0
# 3    12.0
# 5     9.0
# Name: runs, dtype: float64

# %%
l1=[1,3,4,2,5]
sorted(l1)
# Out:
# [1, 2, 3, 4, 5]

# %%
data=pd.read_csv('bollywood.csv')
movies=data['lead'].squeeze()
count=movies.value_counts()
count[count>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64
